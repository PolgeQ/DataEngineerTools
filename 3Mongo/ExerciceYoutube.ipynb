# %% [markdown]
# # Consignes
#
# Intégrer le fichier USvideos.csv qui représente un ensemble de 8000 vidéos Youtube.
#
# Merger le fichier US_category_id.json pour récupérer le nom des catégories. Il conviendra de bien spécifier l'ID du document.
#
#
# # Questions
# - 1) Récupérer toutes les vidéos de la chaîne Apple.
# - 2) Compter le nombre de catégories différentes
# - 3) Si vous ne l'avez pas déjà fait, découper les tags en listes et mettre à jour les tags de chacun des documents avec une requête update.
# - 4) Récupérer les vidéos les plus vues.
# - 5) Compter le nombre moyen de vues en fonction de la catégorie.
# - 6) Récupérer les chaines Youtube avec la plus grande moyenne de likes.

# %%
# !pip install pymongo

# %%
import pandas as pd
import pymongo
import json

# %%
client = pymongo.MongoClient()
database = client['exercices']
collection = database['youtube']

# %%
df_youtube = pd.read_csv("./data/USvideos.csv")
df_youtube.head(2)
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
#
#       channel_title  category_id  \
# 0  Logan Paul Vlogs           24
# 1             Apple           28
#
#                                                 tags    views   likes  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 1  Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lig...  7860119  185853
#
#    dislikes  comment_total                                  thumbnail_link  \
# 0      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 1     26679              0  https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg
#
#     date
# 0  13.09
# 1  13.09

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_youtube["tags"] = df_youtube["tags"].apply(lambda x: x.split("|"))

# %% [markdown]
# ### Importer les données

# %%
collection.delete_many({})

# %%
collection.insert_many(df_youtube.to_dict(orient='records'))

# %% [markdown]
# ## Question 1

# %%
cursor = collection.find({"channel_title":"Apple"})
list(cursor)
# Out:
# [{'_id': ObjectId('61f6f1661c5f8e4b5a32efc6'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': ['Apple',
#    'iPhone 10',
#    'iPhone Ten',
#    'iPhone',
#    'Portrait Lighting',
#    'A11 Bionic',
#    'augmented reality',
#    'emoji',
#    'animoji',
#    'Face ID',
#    'Apple Pay',
#    'camera',
#    'smartphone'],
#   'views': 7860119,
#   'likes': 185853,
#   'dislikes': 26679,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 13.09},
#  {'_id': ObjectId('61f6f1661c5f8e4b5a32f090'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': ['Apple',
#    'iPhone 10',
#    'iPhone Ten',
#    'iPhone',
#    'Portrait Lighting',
#    'A11 Bionic',
#    'augmented reality',
#    'emoji',
#    'animoji',
#    'Face ID',
# ...

# %% [markdown]
# ## Question 2

# %%
len(collection.distinct('category_id'))
# Out:
# 16

# %% [markdown]
# ## Question 3

# %% [markdown]
# ## Question 4

# %%
cursor = collection.find().sort([("views",-1)]).limit(10)
list(cursor)
# Out:
# [{'_id': ObjectId('61f6f1661c5f8e4b5a32f738'),
#   'video_id': 'MBdVXkSdhwU',
#   'title': "BTS (방탄소년단) 'DNA' Official MV",
#   'channel_title': 'ibighit',
#   'category_id': 10,
#   'tags': ['BIGHIT', '빅히트', '방탄소년단', 'BTS', 'BANGTAN', '방탄'],
#   'views': 41500672,
#   'likes': 2010366,
#   'dislikes': 78076,
#   'comment_total': 736179,
#   'thumbnail_link': 'https://i.ytimg.com/vi/MBdVXkSdhwU/default.jpg',
#   'date': 22.09},
#  {'_id': ObjectId('61f6f1661c5f8e4b5a32f663'),
#   'video_id': 'MBdVXkSdhwU',
#   'title': "BTS (방탄소년단) 'DNA' Official MV",
#   'channel_title': 'ibighit',
#   'category_id': 10,
#   'tags': ['BIGHIT', '빅히트', '방탄소년단', 'BTS', 'BANGTAN', '방탄'],
#   'views': 38013692,
#   'likes': 1950475,
#   'dislikes': 75294,
#   'comment_total': 713293,
#   'thumbnail_link': 'https://i.ytimg.com/vi/MBdVXkSdhwU/default.jpg',
#   'date': 21.09},
#  {'_id': ObjectId('61f6f1661c5f8e4b5a32f076'),
#   'video_id': 'tt2k8PGm-TI',
#   'title': 'ZAYN - Dusk Till Dawn ft. Sia',
# ...

# %% [markdown]
# ## Question 5

# %%
cursor = collection.aggregate([{"$group" : {"_id" : "$category_id", "avgViewsCategory" : {"$avg" :"$views"}}}])
list(cursor)
# Out:
# [{'_id': 20, 'avgViewsCategory': 681081.8170731707},
#  {'_id': 10, 'avgViewsCategory': 1176553.612},
#  {'_id': 27, 'avgViewsCategory': 547582.4700598803},
#  {'_id': 29, 'avgViewsCategory': 1110334.2142857143},
#  {'_id': 24, 'avgViewsCategory': 1154868.4397251718},
#  {'_id': 19, 'avgViewsCategory': 464041.0833333333},
#  {'_id': 26, 'avgViewsCategory': 537665.1806674339},
#  {'_id': 2, 'avgViewsCategory': 607693.8706896552},
#  {'_id': 17, 'avgViewsCategory': 728434.3243902439},
#  {'_id': 23, 'avgViewsCategory': 1240073.294039735},
#  {'_id': 15, 'avgViewsCategory': 651404.3879310344},
#  {'_id': 22, 'avgViewsCategory': 971532.7573696146},
#  {'_id': 43, 'avgViewsCategory': 8492.5},
#  {'_id': 1, 'avgViewsCategory': 1039472.6560846561},
#  {'_id': 28, 'avgViewsCategory': 924730.548828125},
#  {'_id': 25, 'avgViewsCategory': 540955.5569823436}]

# %% [markdown]
# ## Question 6

# %%
cursor = collection.aggregate([{"$group":{"_id":"$channel_title","avgLike":{"$avg":"$likes"}}},{"$sort" :{"avgLike": -1}},{"$limit":10}])
list(cursor)
# Out:
# [{'_id': 'ZaynVEVO', 'avgLike': 1431683.0},
#  {'_id': 'ibighit', 'avgLike': 1371766.25},
#  {'_id': 'melanie martinez', 'avgLike': 911871.5},
#  {'_id': 'BETNetworks', 'avgLike': 769687.625},
#  {'_id': 'jypentertainment', 'avgLike': 758826.6666666666},
#  {'_id': 'Logan Paul Vlogs', 'avgLike': 653443.5384615385},
#  {'_id': 'Wengie', 'avgLike': 567235.2},
#  {'_id': 'Alesso', 'avgLike': 509417.28571428574},
#  {'_id': 'PewDiePie', 'avgLike': 508647.8},
#  {'_id': 'shakiraVEVO', 'avgLike': 434302.14285714284}]
